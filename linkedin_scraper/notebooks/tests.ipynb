# %%
import pandas as pd

# %%
df = pd.read_json("data/linkedin_jobs.json")

# %%
# Load the JSON
df = pd.read_json("data/linkedin_jobs.json")

# Drop duplicate rows
df_unique = df.drop_duplicates()

# (Optional) Reset the index
df_unique.reset_index(drop=True, inplace=True)

# Preview
df_unique
# Out:
#          job_id                                            job_url  \
# 0    4199363919  https://in.linkedin.com/jobs/view/devops-engin...
# 1    4205907479  https://in.linkedin.com/jobs/view/devops-engin...
# 2    4159283422  https://www.linkedin.com/jobs/view/devops-engi...
# 3    4150490838  https://www.linkedin.com/jobs/view/devops-engi...
# 4    4215304968  https://ca.linkedin.com/jobs/view/devops-engin...
# ..          ...                                                ...
# 142  4214785256  https://ca.linkedin.com/jobs/view/data-analyst...
# 143  4200093026  https://ca.linkedin.com/jobs/view/associate-da...
# 144  4213592616  https://ca.linkedin.com/jobs/view/data-analyst...
# 145  4117383909  https://ca.linkedin.com/jobs/view/data-analyst...
# 146  4211125209  https://ca.linkedin.com/jobs/view/insights-ana...
#
#                                              job_title  \
# 0                                      DevOps Engineer
# ...
